# %% [markdown]
# #  WORD NET LEMMATIZER

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
'''Pos - Noun-n
verb - v
adjective - a
adverb - r
'''
lemmatizer.lemmatize('going',pos = 'v')
# Out:
# 'go'

# %%
words = ["eating","eats","eaten","writing","writes","programming","programs"]

# %%
for word in words:
    print(word+"----->"+ lemmatizer.lemmatize(word ,pos = 'v'))
# Out:
# eating----->eat
# eats----->eat
# eaten----->eat
# writing----->write
# writes----->write
# programming----->program
# programs----->program

# %%
lemmatizer.lemmatize('goes' ,pos = 'v')
# Out:
# 'go'

# %%
lemmatizer.lemmatize('fairly' ,pos = 'v') , lemmatizer.lemmatize('spprtingly' ,pos = 'v')
# Out:
# ('fairly', 'spprtingly')
